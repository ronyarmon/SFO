# %%
year=str(years[0])
data=years_data_dicts[year]

yaqu_f=pd.DataFrame(years_data_dicts[str(year)])
yaqu_f=yaqu_f.sort_index(axis='index', ascending=True)
yaqu_f.index.name = 'Rating'
print ('Year:',year,'\nData:\n',yaqu_f)

yaqu_f['Rating']=yaqu_f.index
yaqu_f_m=pd.melt(frame=yaqu_f,id_vars='Rating',value_name='f') #melt yaqu_f to prepare for stacked bar chart
yaqu_f_m.rename(columns = {'variable':'Question'}, inplace = True)
yaqu_f_m=yaqu_f_m[['Question','Rating','f']]
    
alt.Chart(yaqu_f_m).mark_bar().encode(
    x=alt.X('sum(f)',axis=alt.Axis(format='%', title='Percentage')),
    y=alt.Y('Question:O', axis=alt.Axis(title='Question')),
    color='Rating:N'    
    ).properties(
        title=year,
    )
# Out:
# Year: 2010
# Data:
#          AIRTRAIN    ALL    ART   FOOD  INFODOWN  INFOUP  LTPARKING   PARK  \
# Rating
# 1          0.007  0.002  0.006  0.012     0.011   0.009      0.017  0.021
# 2          0.033  0.016  0.049  0.087     0.064   0.053      0.052  0.061
# 3          0.154  0.228  0.311  0.414     0.352   0.339      0.292  0.275
# 4          0.428  0.564  0.402  0.380     0.383   0.397      0.406  0.430
# 5          0.379  0.190  0.232  0.107     0.190   0.201      0.233  0.212
#
#         RENTAL  ROADS  SCREENS   SIGN  STORE  WALKWAYS
# Rating
# 1        0.028  0.011    0.009  0.013  0.009     0.003
# 2        0.080  0.056    0.047  0.045  0.081     0.026
# 3        0.254  0.217    0.252  0.227  0.440     0.222
# 4        0.409  0.452    0.406  0.435  0.356     0.421
# 5        0.230  0.263    0.285  0.281  0.114     0.328
# <div class="vega-embed" id="f594d7e1-df5e-4728-ac94-8b2a8d6bed34"></div>
#
# <style>
# .vega-embed .vega-actions > a {
# ...

# %%
year=str(years[2])
data=years_data_dicts[year]

yaqu_f=pd.DataFrame(years_data_dicts[str(year)])
yaqu_f=yaqu_f.sort_index(axis='index', ascending=True)
yaqu_f.index.name = 'Rating'
print ('Year:',year,'\nData:\n',yaqu_f)

yaqu_f['Rating']=yaqu_f.index
yaqu_f_m=pd.melt(frame=yaqu_f,id_vars='Rating',value_name='f') #melt yaqu_f to prepare for stacked bar chart
yaqu_f_m.rename(columns = {'variable':'Question'}, inplace = True)
yaqu_f_m=yaqu_f_m[['Question','Rating','f']]
    
alt.Chart(yaqu_f_m).mark_bar().encode(
    x=alt.X('sum(f)',axis=alt.Axis(format='%', title='Percentage')),
    y=alt.Y('Question:O', axis=alt.Axis(title='Question')),
    color='Rating:N'    
    ).properties(
        title=year,
    )
# Out:
# Year: 2012
# Data:
#          AIRTRAIN    ALL    ART   FOOD  INFODOWN  INFOUP  LTPARKING   PARK  \
# Rating
# 1          0.012  0.002  0.004  0.012     0.016   0.012      0.021  0.014
# 2          0.038  0.019  0.030  0.069     0.048   0.044      0.058  0.063
# 3          0.187  0.191  0.254  0.349     0.307   0.300      0.302  0.276
# 4          0.407  0.554  0.412  0.404     0.386   0.371      0.375  0.407
# 5          0.357  0.234  0.299  0.166     0.244   0.273      0.244  0.240
#
#         RENTAL  ROADS  SCREENS   SIGN  STORE  WALKWAYS
# Rating
# 1        0.019  0.009    0.006  0.007  0.009     0.003
# 2        0.068  0.056    0.026  0.032  0.068     0.022
# 3        0.263  0.227    0.192  0.185  0.370     0.182
# 4        0.409  0.435    0.424  0.451  0.403     0.429
# 5        0.242  0.273    0.352  0.325  0.151     0.364
# <div class="vega-embed" id="fb2e3113-4bc1-4c00-8ed6-bac7bcdd8dca"></div>
#
# <style>
# .vega-embed .vega-actions > a {
# ...

# %%
year=str(years[4])
data=years_data_dicts[year]

yaqu_f=pd.DataFrame(years_data_dicts[str(year)])
yaqu_f=yaqu_f.sort_index(axis='index', ascending=True)
yaqu_f.index.name = 'Rating'
print ('Year:',year,'\nData:\n',yaqu_f)

yaqu_f['Rating']=yaqu_f.index
yaqu_f_m=pd.melt(frame=yaqu_f,id_vars='Rating',value_name='f') #melt yaqu_f to prepare for stacked bar chart
yaqu_f_m.rename(columns = {'variable':'Question'}, inplace = True)
yaqu_f_m=yaqu_f_m[['Question','Rating','f']]
    
print ('\nMarks: 1 (unacceptable) - 5 (outstanding)')
alt.Chart(yaqu_f_m).mark_bar().encode(
    x=alt.X('sum(f)',axis=alt.Axis(format='%', title='Percentage')),
    y=alt.Y('Question:O', axis=alt.Axis(title='Question')),
    color='Rating:N'    
    ).properties(
        title=year,
    )
# Out:
# Year: 2014
# Data:
#          AIRTRAIN    ALL    ART   FOOD  INFODOWN  INFOUP  LTPARKING   PARK  \
# Rating
# 1          0.009  0.002  0.007  0.013     0.011   0.009      0.019  0.023
# 2          0.028  0.014  0.040  0.085     0.032   0.026      0.065  0.055
# 3          0.187  0.195  0.278  0.357     0.316   0.317      0.275  0.273
# 4          0.426  0.563  0.384  0.399     0.388   0.390      0.392  0.405
# 5          0.350  0.226  0.292  0.146     0.252   0.258      0.250  0.243
#
#         RENTAL  ROADS  SCREENS   SIGN  STORE  WALKWAYS   WIFI
# Rating
# 1        0.030  0.011    0.004  0.010  0.011     0.004  0.052
# 2        0.086  0.046    0.023  0.036  0.074     0.021  0.064
# 3        0.259  0.215    0.218  0.205  0.370     0.201  0.180
# 4        0.384  0.442    0.426  0.434  0.398     0.431  0.327
# 5        0.241  0.287    0.329  0.316  0.147     0.342  0.376
#
# Marks: 1 (unacceptable) - 5 (outstanding)
# ...

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
